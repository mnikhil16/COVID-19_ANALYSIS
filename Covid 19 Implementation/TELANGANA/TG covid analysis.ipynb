# %% [markdown]
# # TG Covid analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import StrMethodFormatter
from datetime import datetime
plt.rcParams['figure.figsize'] = [20,12]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
def get_monthday(date):
    date=date.split("-")
    if date[1]=="01":
        return "January"+date[0]
    if date[1]=="02":
        return "February"+date[0]
    if date[1]=="03":
        return "March"+date[0]
    if date[1]=="04":
        return "April"+date[0]
    if date[1]=="05":
        return "May"+date[0]
    if date[1]=="06":
        return "June"+date[0]
    if date[1]=="07":
        return "July"+date[0]
    if date[1]=="08":
        return "August"+date[0]
    if date[1]=="09":
        return "September"+date[0]
    if date[1]=="10":
        return "October"+date[0]
    if date[1]=="11":
        return "November"+date[0]
    if date[1]=="12":
        return "December"+date[0]
def get_month(date):
    date=date.split("-")
    if date[1]=="01":
        return "January"+date[2]
    if date[1]=="02":
        return "February"+date[2]
    if date[1]=="03":
        return "March"+date[2]
    if date[1]=="04":
        return "April"+date[2]
    if date[1]=="05":
        return "May"+date[2]
    if date[1]=="06":
        return "June"+date[2]
    if date[1]=="07":
        return "July"+date[2]
    if date[1]=="08":
        return "August"+date[2]
    if date[1]=="09":
        return "September"+date[2]
    if date[1]=="10":
        return "October"+date[2]
    if date[1]=="11":
        return "November"+date[2]
    if date[1]=="12":
        return "December"+date[2]
    
def get_year(date):
    date=date.split("-")
    return date[0]
def Histogram(x,y,xlabel,ylabel,title):
    x.plot(kind="hist",
        alpha=0.7,
        #         bins=[1000,2000,3000,4000,5000,6000,7000,8000,9000,10000,15000],
        title=title,
        figsize=(12,8),
        color=["red"],rwidth=0.8
       )
    y.plot(kind="hist",
        alpha=0.7,
        #         bins=[1000,2000,3000,4000,5000,6000,7000,8000,9000,10000,15000],
        title=title,
        figsize=(12,8),
        color=["blue"],rwidth=0.8
       )
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.show()
def bar_graph(categories,cat_val,xlabel,ylabel,title="",color="blue"):
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.bar(categories,cat_val,width=0.8,color=color)
    plt.title(title)
    plt.show()
# This is the code of linear_regression model also.........           
def linear_correlation(x,y):
    meanx=sum(x.values)/len(x)
    meany=sum(y.values)/len(y)
    if len(x.values)==len(y.values):
        num,den=0,0
        #numerator calculation
        a=0
        for i in range(len(x)):
            a+=x.values[i]*y.values[i]
            #         print(a)
        num=a*len(x)-(sum(x.values)*sum(y.values))
    
        #denominator calculation
        ax,ay=0,0
        for i in range(len(x)):
                ax+=x.values[i]**2
                ay+=y.values[i]**2 
        p1=(len(x)*ax-(sum(x.values)**2))**0.5
        p2=(len(y)*ay-(sum(y.values)**2))**0.5
        den=p1*p2
        #print(num,den)
        return num/den
    else:
        raise Exception("Invalid Dimension")
import datetime
import calendar
 
def get_day(date):
    day, month, year = (int(i) for i in date.split('-'))   
    dayNumber = calendar.weekday(year, month, day)
    days =["Monday", "Tuesday", "Wednesday", "Thursday",
                         "Friday", "Saturday", "Sunday"]
    return (days[dayNumber])

def set_index(x):
    if x=="June2020":
        return -2
    if x=="July2020":
        return -1
    if x=="August2020":
        return 0
    if x=="September2020":
        return 1
    if x=="October2020":
        return 2
    if x=="November2020":
        return 3
    if x=="December2020":
        return 4
    if x=="January2021":
        return 5
    if x=="February2021":
        return 6
    if x=="March2021":
        return 7
    if x=="April2021":
        return 8
    if x=="May2021":
        return 9
    if x=="June2021":
        return 10
    if x=="July2021":
        return 11
    if x=="August2021":
        return 12
    if x=="September2021":
        return 13
    if x=="October2021":
        return 14
    if x=="November2021":
        return 15
    if x=="December2021":
        return 16
    if x=="January2022":
        return 17
def piechart(categories,cat_val,title=""):
    labels=categories
    values=cat_val
    #     explode = (0,0.1)
    plt.pie(values,labels=values,counterclock=False,autopct="%.2f", shadow=True)
    plt.title(title)
    plt.legend(labels,loc=3)
    plt.rcParams['figure.figsize'] = [10,50]
    plt.show()
def rearrange_date(x):
    arr=x.split("-")
    s="-"
    s1=s.join(arr[::-1])
    return s1
# vacc_month_sum[["vax_total_24h","vax_first_dose_24h","vax_sec_dose_24h"]].plot(kind="bar")
def plot_bar_graphs(data,values,xlabel="",ylabel="",title=""):
    data[values].plot(kind="bar",title="",xlabel=xlabel,ylabel=ylabel)
def variant(date):
    date = date.split('-')
    if date[0] == '2020':
        return 'alpha'
    elif date[0] == '2021':
        if (date[1] == '01' or date[1] == '02' or date[1] == '03'):
            return 'alpha'
        elif date[1] == '12':
            return 'omicron'
        else:
            return 'delta'
    elif date[0] == '2022':
        return 'omicron'
def TPR(total_tests,positive):
    return (positive/total_tests)*100
def comorb(s):
    if s=="no comorbidity":
        return "no comorbidity"
    else:
        return "comorbidity"
def cato(s):
    if "Government" in s or "Govt" in s or "govt" in s or "government" in s:
        return "Government facility"
    if "Private" in s :
        return "Private facility"
    if "college" in s:
        return "Medical college"
    else:
        return "Others"
def order_by_date(date):
    date=date.split("-")
    s=""
    for i in range(len(date)-1,-1,-1):
        s=s+date[i]

    return int(s)

# %%
TGcaseinfo=pd.read_csv("/content/drive/MyDrive/Covid 19 Implementation/TELANGANA/TG_case_info.csv")
TGage_gender=pd.read_csv("/content/drive/MyDrive/Covid 19 Implementation/TELANGANA/TG_age_gender_dist.csv")
TGsymptomatic=pd.read_csv("/content/drive/MyDrive/Covid 19 Implementation/TELANGANA/TG_symptomatic.csv")
TGcontact=pd.read_csv("/content/drive/MyDrive/Covid 19 Implementation/TELANGANA/TG_contact_testing.csv")

# %%
TGcaseinfo["month"]=TGcaseinfo["date"].copy()
TGcaseinfo["year"]=TGcaseinfo["date"].copy()
TGcaseinfo["month"]=TGcaseinfo["month"].apply(lambda x:get_month(x))
TGcaseinfo["year"]=TGcaseinfo["year"].apply(lambda x:get_year(x))
TGcaseinfo['rise in cases']= ""
TGcaseinfo['rise in cases'] = TGcaseinfo['cases_new'].diff()
TGcaseinfo.dropna(subset=['rise in cases'],inplace=True)

# %%
TGcaseinfo
# Out:
#            date  cases_new  cases_total  recovered_new  recovered_total  \
# 1    02-09-2020       2892       130589           2240            97402
# 2    03-09-2020       2817       133406           2611           100013
# 3    04-09-2020       2478       135884           2011           102024
# 4    05-09-2020       2511       138395           2579           104603
# 5    06-09-2020       2574       140969           2927           107530
# ..          ...        ...          ...            ...              ...
# 423  01-01-2022        317       682215            232           674453
# 424  02-01-2022        274       682489            227           674680
# 425  03-01-2022        482       682971            212           674892
# 426  04-01-2022       1052       684023            240           675132
# 427  05-01-2022       1520       685543            209           675341
#
#      deaths_new  deaths_total  cases_in_isolation  state_CFR  national_CFR  \
# 1            10           846               25271       0.64          1.76
# 2            10           856               25293       0.64          1.75
# 3            10           866               25730       0.63          1.74
# 4            11           877               25729       0.63          1.73
# 5             9           886               25449       0.62          1.71
# ..          ...           ...                 ...        ...           ...
# 423           2          4029                3733        NaN          0.59
# 424           1          4030                3779        NaN          0.59
# 425           1          4031                4048        NaN          0.59
# 426           2          4033                4858        NaN          0.58
# 427           1          4034                6168        NaN          0.58
#
#      state_recovery_rate  national_recovery_rate          month year  \
# 1                   74.5                   77.02  September2020   02
# 2                   74.9                   77.09  September2020   03
# 3                   75.0                   77.14  September2020   04
# 4                   75.5                   77.24  September2020   05
# 5                   76.2                   77.29  September2020   06
# ..                   ...                     ...            ...  ...
# 423                  NaN                   98.86    January2022   01
# 424                  NaN                   98.85    January2022   02
# 425                  NaN                   98.81    January2022   03
# 426                  NaN                   98.70    January2022   04
# 427                  NaN                   98.51    January2022   05
#
#      rise in cases
# 1            158.0
# 2            -75.0
# 3           -339.0
# 4             33.0
# 5             63.0
# ..             ...
# 423            6.0
# 424          -43.0
# 425          208.0
# 426          570.0
# 427          468.0
#
# [427 rows x 15 columns]

# %% [markdown]
# # PART1: COVID-WAVES AND ITS POTENTIAL CAUSES:

# %% [markdown]
# ## Graph1
# **The below graph plots no of positives cases, discharged patients, and deaths per day**

# %% [markdown]
# PROPERTIES OF GRAPH1:
# Blue curve:
#
# 1) If the curve is going up --> means number of cases per day are increasing 2) If the curve is going down --> means the number of cases per day are decreasing 3) If the curve is flat --> means there is no change in the number cases per day
#
# Orange curve:
#
# 1) If the curve is going up --> means number of discharged patients per day is increasing 2) If the curve is going down --> means the number of discharged patients per day is decreasing 3) If the curve is flat --> means there is no change in the number discharged patients per day
#
# Green curve:
#
# 1) If the curve is going up --> means number of deaths per day is increasing 2) If the curve is going down --> means the number of deaths per day is decreasing 3) If the curve is flat --> means there is no change in the number deaths per day

# %%
plt.rcParams['figure.figsize'] = [25,12]
plt.xlabel("date")
plt.plot(TGcaseinfo["date"],TGcaseinfo["cases_new"], linestyle='-')
plt.plot(TGcaseinfo["date"],TGcaseinfo["recovered_new"], linestyle='-')
plt.plot(TGcaseinfo["date"],TGcaseinfo["deaths_new"], linestyle='-')
plt.legend(["cases_new","recovered_new","deaths_new"])

# %% [markdown]
# ## Graph2
# **PHASE-1: SEPTEMBER2020 to DECEMBER2020**

# %% [markdown]
# PROPERTIES OF GRAPH2:
# Blue curve:
#
# 1) If the curve is going up --> means number of cases per day are increasing 2) If the curve is going down --> means the number of cases per day are decreasing 3) If the curve is flat --> means there is no change in the number cases per day
#
# Orange curve:
#
# 1) If the curve is going up --> means number of discharged patients per day is increasing 2) If the curve is going down --> means the number of discharged patients per day is decreasing 3) If the curve is flat --> means there is no change in the number discharged patients per day
#
# Green curve:
#
# 1) If the curve is going up --> means number of deaths per day is increasing 2) If the curve is going down --> means the number of deaths per day is decreasing 3) If the curve is flat --> means there is no change in the number deaths per day

# %%
plt.rcParams['figure.figsize'] = [15,12]
plt.xlabel("date")
plt.plot(TGcaseinfo["date"][:list(TGcaseinfo["date"]).index("01-01-2021")],TGcaseinfo["cases_new"][:list(TGcaseinfo["date"]).index("01-01-2021")], linestyle='-')
plt.plot(TGcaseinfo["date"][:list(TGcaseinfo["date"]).index("01-01-2021")],TGcaseinfo["recovered_new"][:list(TGcaseinfo["date"]).index("01-01-2021")], linestyle='-')
plt.plot(TGcaseinfo["date"][:list(TGcaseinfo["date"]).index("01-01-2021")],TGcaseinfo["deaths_new"][:list(TGcaseinfo["date"]).index("01-01-2021")], linestyle='-')
plt.legend(["cases_new","recovered_new","deaths_new"])

# %% [markdown]
# ## Graph3
# **PHASE2: JANUARY-2021 to SEPTEMBER-2021:**

# %% [markdown]
# PROPERTIES OF GRAPH3:
# Blue curve:
#
# 1) If the curve is going up --> means number of cases per day are increasing 2) If the curve is going down --> means the number of cases per day are decreasing 3) If the curve is flat --> means there is no change in the number cases per day
#
# Orange curve:
#
# 1) If the curve is going up --> means number of discharged patients per day is increasing 2) If the curve is going down --> means the number of discharged patients per day is decreasing 3) If the curve is flat --> means there is no change in the number discharged patients per day
#
# Green curve:
#
# 1) If the curve is going up --> means number of deaths per day is increasing 2) If the curve is going down --> means the number of deaths per day is decreasing 3) If the curve is flat --> means there is no change in the number deaths per day

# %%
plt.rcParams['figure.figsize'] = [15,12]
plt.xlabel("date")
plt.plot(TGcaseinfo["date"][list(TGcaseinfo["date"]).index("01-01-2021"):list(TGcaseinfo["date"]).index("01-09-2021")],TGcaseinfo["cases_new"][list(TGcaseinfo["date"]).index("01-01-2021"):list(TGcaseinfo["date"]).index("01-09-2021")], linestyle='-')
plt.plot(TGcaseinfo["date"][list(TGcaseinfo["date"]).index("01-01-2021"):list(TGcaseinfo["date"]).index("01-09-2021")],TGcaseinfo["recovered_new"][list(TGcaseinfo["date"]).index("01-01-2021"):list(TGcaseinfo["date"]).index("01-09-2021")], linestyle='-')
plt.plot(TGcaseinfo["date"][list(TGcaseinfo["date"]).index("01-01-2021"):list(TGcaseinfo["date"]).index("01-09-2021")],TGcaseinfo["deaths_new"][list(TGcaseinfo["date"]).index("01-01-2021"):list(TGcaseinfo["date"]).index("01-09-2021")], linestyle='-')
plt.legend(["cases_new","recovered_new","deaths_new"])

# %% [markdown]
# **From Graph1, Graph2, Graph3 we can observe that during the first phase that is SEPTEMBER2020 to DECEMBER2020 the cases gradually reduced but we can see a huge surge in cases during second phase that is JANUARY2021 to SEPTEMBER2021 one major reason can be delay and shortage of vacines source:https://www.thenewsminute.com/article/vaccine-shortage-hyderabad-delays-vaccination-people-18-category-149787**
# **We can also observe that the no. of recovered cases also had a very big surge which is a very good thing

# %%
TGcaseinfosum=TGcaseinfo.groupby("month").agg("sum").reset_index()
TGcaseinfosum["index"]=TGcaseinfosum["month"].copy()
TGcaseinfosum["index"]=TGcaseinfosum["index"].apply(lambda x: set_index(x))
TGcaseinfosum.sort_values(by="index",inplace=True)
TGcaseinfosum
# Out:
#             month  cases_new  cases_total  recovered_new  recovered_total  \
# 15  September2020      61887      4564158          63060          3669486
# 13    October2020      45801      6518482          56468          5785559
# 11   November2020      31184      7704031          39289          7214322
# 2    December2020      10294      5627519          11772          5459620
# 5     January2021       7766      8435664          11148          8266633
# 4    February2021       4162      8007374           4429          7914455
# 9       March2021       9082      9370293           6005          9236069
# 0       April2021      43535      5851885          11336          5496312
# 10        May2021      80990     11965413         112509         10883721
# 8        June2021      45159     18163783          65475         17421533
# 7        July2021      20820     19043129          24928         18618080
# 1      August2021      12196     18919830          15216         18595435
# 16  September2021       7492     18542950           8530         18288059
# 14    October2021       4694     17382046           5132         17170731
# 12   November2021       2338     10794056           2456         10672514
# 3    December2021       5337     19018335           5354         18802591
# 6     January2022       3645      3417241           1120          3374498
#
#     deaths_new  deaths_total  cases_in_isolation  state_CFR  national_CFR  \
# 15         282         27811              682224      16.97         45.89
# 13         203         37371              574717      17.08         45.46
# 11         122         42122              372224      16.28         45.00
# 2           55         30256               95023      10.60         29.30
# 5           55         45606               68700      15.58         40.60
# 4           34         43656               19630      14.58         37.80
# 9           63         51465               33104      16.88         43.00
# 0          127         31555              203598       9.64         22.90
# 10         542         67192             1014500      12.25         24.70
# 8          380        105039              637211      17.19         37.90
# 7          139        112334              312715      17.58         39.00
# 1           66        111438              213098      16.82         37.70
# 16          44        109145              145746      16.24         36.40
# 14          31        102307              109008      15.10         33.80
# 12          18         63707               57835       0.00          1.16
# 3           31        112342              103402       0.00         15.34
# 6            7         20157               22586       0.00          2.93
#
#     state_recovery_rate  national_recovery_rate  rise in cases  index
# 15              2241.61                 2221.22         -631.0      1
# 13              2657.85                 2618.41         -572.0      2
# 11              2806.71                 2790.00         -938.0      3
# 2               1940.19                 1908.90         -119.0      4
# 5               2841.70                 2799.60         -277.0      5
# 4               2668.54                 2624.50          -19.0      6
# 9               3055.53                 2980.70          506.0      7
# 0               1692.49                 1633.70         4409.0      8
# 10              1999.22                 1910.70        -2569.0      9
# 8               2876.57                 2856.91        -1607.0     10
# 7               2932.85                 2916.77         -303.0     11
# 1               2850.13                 2826.44         -274.0     12
# 16              2761.36                 2732.29         -126.0     13
# 14              2568.26                 2548.53          -43.0     14
# 12                 0.00                 1581.89           13.0     15
# 3                  0.00                 2768.03          127.0     16
# 6                  0.00                  493.73         1209.0     17

# %% [markdown]
# ## Graph4
# **The below graph plots total no of positives cases per every month from July 2020 to January 2022**

# %%
plt.rcParams['figure.figsize'] = [30,12]
bar_graph(TGcaseinfosum["month"],TGcaseinfosum["cases_new"],"Month","Total no of cases","Total no cases in each month")

# %% [markdown]
# **Conclusions from The above graph:
# As we can see the highest no of cases can be seen in september2020, october2020, april2021, May2021, June2021**

# %% [markdown]
# ## Graph5
# **The below bar graph plots total deaths in each month**

# %%
plt.rcParams['figure.figsize'] = [30,12]
bar_graph(TGcaseinfosum["month"],TGcaseinfosum["deaths_new"],"Month","Total no of cases","Total no cases in each month","orange")

# %% [markdown]
# **Conclusions from The above graph:
# As we can see the highest no of deaths can be seen in september2020, May2021, June2021**

# %% [markdown]
# ## Graph7
# **The below graph plots State CFR vs National CFR**

# %% [markdown]
# **PROPERTIES OF GRAPH7**:
# **Blue curve**:
#
# **1)** If the curve is going up --> means State CFR is increasing
# **2)** If the curve is going down --> means State CFR is decreasing
# **3)** If the curve is flat --> means there is no change in the State CFR
#
# **Orange curve**:
#
# **1)** If the curve is going up --> means number of National CFR is increasing
# **2)** If the curve is going down --> means the National CFR is decreasing
# **3)** If the curve is flat --> means there is no change in the National CFR

# %%
plt.rcParams['figure.figsize'] = [15,12]
plt.xlabel("date")
plt.ylabel("CFR")
plt.plot(TGcaseinfo["date"],TGcaseinfo["state_CFR"])
plt.plot(TGcaseinfo["date"],TGcaseinfo["national_CFR"])
plt.legend(["state_CFR","national_CFR"])

# %% [markdown]
# **From above graph we can observe that the the states CFR(case fatality rate) is very less compared to national CFR**

# %% [markdown]
# ## Graph8
# **The below graph plots home isolations per day**

# %% [markdown]
# **PROPERTIES OF GRAPH8**:
# **Red curve**:
#
# **1)** If the curve is going up --> means no. of home isolations are increasing
# **2)** If the curve is going down --> means no. of home isolations are decreasing
# **3)** If the curve is flat --> means there is no change in the no. of home isolations

# %%
plt.rcParams['figure.figsize'] = [15,12]
plt.xlabel("date")
plt.ylabel("CFR")
plt.plot(TGcaseinfo["date"],TGcaseinfo["cases_in_isolation"],color="red")

# %% [markdown]
# **From Graph6 we can observe that the no of home isolations drastically increased during second phase**

# %%
TGage_gendermean=TGage_gender.mean().reset_index()
age=[]
mean=[]
for i in range(len(list(TGage_gendermean["index"]))):
    if TGage_gendermean["index"][i]=="total_total" or TGage_gendermean["index"][i]=="total_male" or TGage_gendermean["index"][i]=="total_female":
        continue
    elif "total" in TGage_gendermean["index"][i]:
        age.append(TGage_gendermean["index"][i])
        mean.append(TGage_gendermean[0][i])
# Out:
# <ipython-input-18-62555eb8814a>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   TGage_gendermean=TGage_gender.mean().reset_index()

# %% [markdown]
# ## Graph7
# **The below piechart plots mean no of cases of each age group**

# %%
piechart(age,mean,"")

# %% [markdown]
# **The highest no of cases can be seen in age groups 20-30, 30-40, 40-50 and 50-60**

# %% [markdown]
# ## Graph8
# **The below graph plots no of primary contacts tested vs no of secondary contacts tested**

# %%
plt.rcParams['figure.figsize'] = [15,12]
plt.plot(TGcontact["date"],TGcontact["primary_contacts_tested_today"],color="violet")
plt.plot(TGcontact["date"],TGcontact["sec_contacts_tested_today"],color="yellow")
plt.legend(["primary_contacts_tested_today","sec_contacts_tested_today"])

# %% [markdown]
# **Description: From Graph 8 we can say that the no. tests conducted for primary contacts is very high compared to secondary contacts**

# %% [markdown]
# ## PREDICTION MODEL

# %%
TGcaseinfo["Index"]=TGcaseinfo["date"].copy()
TGcaseinfo["Index"]=TGcaseinfo["Index"].apply(lambda x: order_by_date(x))
TGcaseinfo.sort_values(by="Index",inplace=True)
TGcaseinfo.to_csv("r4.csv")

# %%
TGcaseinfo.reset_index(inplace=True)
pred_data=TGcaseinfo.copy()

# %%
pred_data
# Out:
#      index        date  cases_new  cases_total  recovered_new  \
# 0        1  02-09-2020       2892       130589           2240
# 1        2  03-09-2020       2817       133406           2611
# 2        3  04-09-2020       2478       135884           2011
# 3        4  05-09-2020       2511       138395           2579
# 4        5  06-09-2020       2574       140969           2927
# ..     ...         ...        ...          ...            ...
# 422    423  01-01-2022        317       682215            232
# 423    424  02-01-2022        274       682489            227
# 424    425  03-01-2022        482       682971            212
# 425    426  04-01-2022       1052       684023            240
# 426    427  05-01-2022       1520       685543            209
#
#      recovered_total  deaths_new  deaths_total  cases_in_isolation  state_CFR  \
# 0              97402          10           846               25271       0.64
# 1             100013          10           856               25293       0.64
# 2             102024          10           866               25730       0.63
# 3             104603          11           877               25729       0.63
# 4             107530           9           886               25449       0.62
# ..               ...         ...           ...                 ...        ...
# 422           674453           2          4029                3733        NaN
# 423           674680           1          4030                3779        NaN
# 424           674892           1          4031                4048        NaN
# 425           675132           2          4033                4858        NaN
# 426           675341           1          4034                6168        NaN
#
#      national_CFR  state_recovery_rate  national_recovery_rate          month  \
# 0            1.76                 74.5                   77.02  September2020
# 1            1.75                 74.9                   77.09  September2020
# 2            1.74                 75.0                   77.14  September2020
# 3            1.73                 75.5                   77.24  September2020
# 4            1.71                 76.2                   77.29  September2020
# ..            ...                  ...                     ...            ...
# 422          0.59                  NaN                   98.86    January2022
# 423          0.59                  NaN                   98.85    January2022
# 424          0.59                  NaN                   98.81    January2022
# 425          0.58                  NaN                   98.70    January2022
# 426          0.58                  NaN                   98.51    January2022
#
#     year  rise in cases     Index
# 0     02          158.0  20200902
# 1     03          -75.0  20200903
# 2     04         -339.0  20200904
# 3     05           33.0  20200905
# 4     06           63.0  20200906
# ..   ...            ...       ...
# 422   01            6.0  20220101
# 423   02          -43.0  20220102
# 424   03          208.0  20220103
# 425   04          570.0  20220104
# 426   05          468.0  20220105
#
# [427 rows x 17 columns]

# %%
# prediction as of 27th January
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
import pandas as pd
import numpy as np
from sklearn import linear_model
import matplotlib
import matplotlib.pyplot as plt
x=pred_data[["index"]]
y=pred_data["cases_total"]

polyfeat = PolynomialFeatures(degree=2)
x = polyfeat.fit_transform(x)
# x
model = linear_model.LinearRegression()
model.fit(x, y)
accuracy=model.score(x,y)
print("Accuracy of Model-1 is {}%".format(round(accuracy*100,2)))
x1=model.predict(polyfeat.fit_transform([[449]]))
print("Predicted Value",int(x1))
print("Actual Value of cumulative case: 751099")
# Out:
# Accuracy of Model-1 is 90.25%
# Predicted Value 777495
# Actual Value of cumulative case: 751099

# %%
# PERFECT MODEL
from sklearn.linear_model import LinearRegression

x=pred_data[["index","recovered_total","cases_new"]]
y=pred_data["cases_total"]
model = LinearRegression().fit(x, y)
accuracy=model.score(x,y)
print("Accuracy of Model is {}%".format(round(accuracy*100,2)))
x1=model.predict([[449,707498,3944]])
print("Predicted Value",int(x1))
print("Actual Value of cumulative case: 751099")
# Out:
# Accuracy of Model is 99.97%
# Predicted Value 751383
# Actual Value of cumulative case: 751099
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %% [markdown]
# **Source:** https://covid19.telangana.gov.in/

# %%
print(linear_correlation(pred_data["recovered_total"],pred_data["cases_total"]))
print(linear_correlation(pred_data["cases_new"],pred_data["cases_total"]))
# Out:
# 0.9981957632663386
# -0.24064510849830437

# %% [markdown]
# DEATH PREDICTION

# %%
# MODEL-1
# prediction as of 27th January
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
import pandas as pd
import numpy as np
from sklearn import linear_model
import matplotlib
import matplotlib.pyplot as plt
x=pred_data[["index","cases_total"]]
y=pred_data["deaths_total"]

polyfeat = PolynomialFeatures(degree=2)
x = polyfeat.fit_transform(x)
# x
model = linear_model.LinearRegression()
model.fit(x, y)
accuracy=model.score(x,y)
print("Accuracy of Model-1 is {}%".format(round(accuracy*100,2)))
x1=model.predict(polyfeat.fit_transform([[449,751384]]))
print("Predicted Value",int(x1))
print("Actual Value of cumulative case: 4081")
# Out:
# Accuracy of Model-1 is 99.99%
# Predicted Value 4587
# Actual Value of cumulative case: 4081

# %%
pred_data
# Out:
#      index        date  cases_new  cases_total  recovered_new  \
# 0        1  02-09-2020       2892       130589           2240
# 1        2  03-09-2020       2817       133406           2611
# 2        3  04-09-2020       2478       135884           2011
# 3        4  05-09-2020       2511       138395           2579
# 4        5  06-09-2020       2574       140969           2927
# ..     ...         ...        ...          ...            ...
# 422    423  01-01-2022        317       682215            232
# 423    424  02-01-2022        274       682489            227
# 424    425  03-01-2022        482       682971            212
# 425    426  04-01-2022       1052       684023            240
# 426    427  05-01-2022       1520       685543            209
#
#      recovered_total  deaths_new  deaths_total  cases_in_isolation  state_CFR  \
# 0              97402          10           846               25271       0.64
# 1             100013          10           856               25293       0.64
# 2             102024          10           866               25730       0.63
# 3             104603          11           877               25729       0.63
# 4             107530           9           886               25449       0.62
# ..               ...         ...           ...                 ...        ...
# 422           674453           2          4029                3733        NaN
# 423           674680           1          4030                3779        NaN
# 424           674892           1          4031                4048        NaN
# 425           675132           2          4033                4858        NaN
# 426           675341           1          4034                6168        NaN
#
#      national_CFR  state_recovery_rate  national_recovery_rate          month  \
# 0            1.76                 74.5                   77.02  September2020
# 1            1.75                 74.9                   77.09  September2020
# 2            1.74                 75.0                   77.14  September2020
# 3            1.73                 75.5                   77.24  September2020
# 4            1.71                 76.2                   77.29  September2020
# ..            ...                  ...                     ...            ...
# 422          0.59                  NaN                   98.86    January2022
# 423          0.59                  NaN                   98.85    January2022
# 424          0.59                  NaN                   98.81    January2022
# 425          0.58                  NaN                   98.70    January2022
# 426          0.58                  NaN                   98.51    January2022
#
#     year  rise in cases     Index
# 0     02          158.0  20200902
# 1     03          -75.0  20200903
# 2     04         -339.0  20200904
# 3     05           33.0  20200905
# 4     06           63.0  20200906
# ..   ...            ...       ...
# 422   01            6.0  20220101
# 423   02          -43.0  20220102
# 424   03          208.0  20220103
# 425   04          570.0  20220104
# 426   05          468.0  20220105
#
# [427 rows x 17 columns]

# %%
# PERFECT MODEL
# prediction as of 27th January.
from sklearn.linear_model import LinearRegression

x=pred_data[["index","recovered_total","cases_total","cases_new"]]
y=pred_data["deaths_total"]
model = LinearRegression().fit(x, y)
accuracy=model.score(x,y)
print("Accuracy of Model is {}%".format(round(accuracy*100,2)))


x1=model.predict([[449,707498,751099,3944]])
print("Predicted cumulative deaths:",round(x1[0],0))
print("Actual Value of cumulative deaths: 4081")
# Out:
# Accuracy of Model is 99.79%
# Predicted cumulative deaths: 4347.0
# Actual Value of cumulative deaths: 4081
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %% [markdown]
# **Source:** https://covid19.telangana.gov.in/

# %%
print(linear_correlation(pred_data["recovered_total"],pred_data["deaths_total"]))
print(linear_correlation(pred_data["cases_total"],pred_data["deaths_total"]))
# Out:
# 0.996848828654258
# 0.9986870804924858
