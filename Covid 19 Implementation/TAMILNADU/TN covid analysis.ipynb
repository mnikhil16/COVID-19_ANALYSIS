# %% [markdown]
# # TN Covid Analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import StrMethodFormatter
from datetime import datetime
plt.rcParams['figure.figsize'] = [20,12]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
def get_monthday(date):
    date=date.split("-")
    if date[1]=="01":
        return "January"+date[0]
    if date[1]=="02":
        return "February"+date[0]
    if date[1]=="03":
        return "March"+date[0]
    if date[1]=="04":
        return "April"+date[0]
    if date[1]=="05":
        return "May"+date[0]
    if date[1]=="06":
        return "June"+date[0]
    if date[1]=="07":
        return "July"+date[0]
    if date[1]=="08":
        return "August"+date[0]
    if date[1]=="09":
        return "September"+date[0]
    if date[1]=="10":
        return "October"+date[0]
    if date[1]=="11":
        return "November"+date[0]
    if date[1]=="12":
        return "December"+date[0]
def get_month(date):
    date=date.split("-")
    if date[1]=="01":
        return "January"+date[2]
    if date[1]=="02":
        return "February"+date[2]
    if date[1]=="03":
        return "March"+date[2]
    if date[1]=="04":
        return "April"+date[2]
    if date[1]=="05":
        return "May"+date[2]
    if date[1]=="06":
        return "June"+date[2]
    if date[1]=="07":
        return "July"+date[2]
    if date[1]=="08":
        return "August"+date[2]
    if date[1]=="09":
        return "September"+date[2]
    if date[1]=="10":
        return "October"+date[2]
    if date[1]=="11":
        return "November"+date[2]
    if date[1]=="12":
        return "December"+date[2]
    
def get_year(date):
    date=date.split("-")
    return date[0]
def Histogram(x,y,xlabel,ylabel,title):
    x.plot(kind="hist",
        alpha=0.7,
        #         bins=[1000,2000,3000,4000,5000,6000,7000,8000,9000,10000,15000],
        title=title,
        figsize=(12,8),
        color=["red"],rwidth=0.8
       )
    y.plot(kind="hist",
        alpha=0.7,
        #         bins=[1000,2000,3000,4000,5000,6000,7000,8000,9000,10000,15000],
        title=title,
        figsize=(12,8),
        color=["blue"],rwidth=0.8
       )
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.show()
def bar_graph(categories,cat_val,xlabel,ylabel,title=""):
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.bar(categories,cat_val,width=0.8)
    plt.title(title)
    plt.show()
# This is the code of linear_regression model also.........           
def linear_correlation(x,y):
    meanx=sum(x.values)/len(x)
    meany=sum(y.values)/len(y)
    if len(x.values)==len(y.values):
        num,den=0,0
        #numerator calculation
        a=0
        for i in range(len(x)):
            a+=x.values[i]*y.values[i]
            #         print(a)
        num=a*len(x)-(sum(x.values)*sum(y.values))
    
        #denominator calculation
        ax,ay=0,0
        for i in range(len(x)):
                ax+=x.values[i]**2
                ay+=y.values[i]**2 
        p1=(len(x)*ax-(sum(x.values)**2))**0.5
        p2=(len(y)*ay-(sum(y.values)**2))**0.5
        den=p1*p2
        #print(num,den)
        return num/den
    else:
        raise Exception("Invalid Dimension")
import datetime
import calendar
 
def get_day(date):
    day, month, year = (int(i) for i in date.split('-'))   
    dayNumber = calendar.weekday(year, month, day)
    days =["Monday", "Tuesday", "Wednesday", "Thursday",
                         "Friday", "Saturday", "Sunday"]
    return (days[dayNumber])

def set_index(x):
    if x=="June2020":
        return -2
    if x=="July2020":
        return -1
    if x=="August2020":
        return 0
    if x=="September2020":
        return 1
    if x=="October2020":
        return 2
    if x=="November2020":
        return 3
    if x=="December2020":
        return 4
    if x=="January2021":
        return 5
    if x=="February2021":
        return 6
    if x=="March2021":
        return 7
    if x=="April2021":
        return 8
    if x=="May2021":
        return 9
    if x=="June2021":
        return 10
    if x=="July2021":
        return 11
    if x=="August2021":
        return 12
    if x=="September2021":
        return 13
    if x=="October2021":
        return 14
    if x=="November2021":
        return 15
    if x=="December2021":
        return 16
    if x=="January2022":
        return 17
def piechart(categories,cat_val,title=""):
    labels=categories
    values=cat_val
    #     explode = (0,0.1)
    plt.pie(values,labels=values,counterclock=False,autopct="%.2f", shadow=True)
    plt.title(title)
    plt.legend(labels,loc=3)
    plt.rcParams['figure.figsize'] = [10,50]
    plt.show()
def rearrange_date(x):
    arr=x.split("-")
    s="-"
    s1=s.join(arr[::-1])
    return s1
# vacc_month_sum[["vax_total_24h","vax_first_dose_24h","vax_sec_dose_24h"]].plot(kind="bar")
def plot_bar_graphs(data,values,xlabel="",ylabel="",title=""):
    data[values].plot(kind="bar",title="",xlabel=xlabel,ylabel=ylabel)
def variant(date):
    date = date.split('-')
    if date[0] == '2020':
        return 'alpha'
    elif date[0] == '2021':
        if (date[1] == '01' or date[1] == '02' or date[1] == '03'):
            return 'alpha'
        elif date[1] == '12':
            return 'omicron'
        else:
            return 'delta'
    elif date[0] == '2022':
        return 'omicron'
def TPR(total_tests,positive):
    return (positive/total_tests)*100
def comorb(s):
    if s=="no comorbidity":
        return "no comorbidity"
    else:
        return "comorbidity"
def cato(s):
    if "Government" in s or "Govt" in s or "govt" in s or "government" in s:
        return "Government facility"
    if "Private" in s :
        return "Private facility"
    if "college" in s:
        return "Medical college"
    else:
        return "Others"

# %%
TMcaseinfo=pd.read_csv("/content/drive/MyDrive/Covid 19 Implementation/TAMILNADU/TN_case_info.csv")
TMcomorbidities=pd.read_csv("/content/drive/MyDrive/Covid 19 Implementation/TAMILNADU/TN_comorbidities_deaths.csv")
TMdistrict=pd.read_csv("/content/drive/MyDrive/Covid 19 Implementation/TAMILNADU/TN_district_details.csv")
TMincoming=pd.read_csv("/content/drive/MyDrive/Covid 19 Implementation/TAMILNADU/TN_incoming_people_till_yesterday.csv")
TNindividual=pd.read_csv("/content/drive/MyDrive/Covid 19 Implementation/TAMILNADU/TN_individual_fatalities.csv",encoding='cp1252')
TMpositive=pd.read_csv("/content/drive/MyDrive/Covid 19 Implementation/TAMILNADU/TN_positive_cases_detail.csv")
TMpositive
# Out:
#            date  active_cases  tested_positive_today  \
# 0    09-08-2020         53336                   5974
# 1    10-08-2020         53099                   5879
# 2    11-08-2020         52810                   5814
# 3    13-08-2020         53499                   5810
# 4    14-08-2020         53716                   5862
# ..          ...           ...                    ...
# 474  01-01-2022          8340                   1470
# 475  02-01-2022          9304                   1575
# 476  03-01-2022         10364                   1727
# 477  04-01-2022         12412                   2683
# 478  05-01-2022         16577                   4824
#
#      tested_positive_till_date  rtpcr_samples_tested_today  \
# 0                       296901                       70186
# 1                       302815                       67153
# 2                       308649                       67492
# 3                       320355                       67275
# 4                       326245                       70153
# ..                         ...                         ...
# 474                    2749534                      103607
# 475                    2751128                      102237
# 476                    2752856                      103119
# 477                    2755587                      103798
# 478                    2760449                      117611
#
#      rtpcr_samples_tested_till_date  persons_tested_rt_pcr_today  \
# 0                           3225805                        68179
# 1                           3292958                        65141
# 2                           3360450                        65490
# 3                           3499300                        65560
# 4                           3569453                        68301
# ..                              ...                          ...
# 474                        57547850                       103403
# 475                        57650087                       102029
# 476                        57753206                       102898
# 477                        57857004                       103573
# 478                        57974615                       117382
#
#      persons_tested_rt_pcr_till_date  male_positive_tests_today  \
# 0                            3109708                       3503
# 1                            3174849                       3532
# 2                            3240339                       3377
# 3                            3375596                       3549
# 4                            3443897                       3518
# ..                               ...                        ...
# 474                         56608042                        895
# 475                         56710071                        954
# 476                         56812969                       1012
# 477                         56916542                       1631
# 478                         57033924                       2893
#
#      female_positive_tests_today  transgender_positive_tests_today  \
# 0                           2489                                 2
# 1                           2382                                 0
# 2                           2457                                 0
# 3                           2286                                 0
# 4                           2372                                 0
# ..                           ...                               ...
# 474                          594                                 0
# 475                          640                                 0
# 476                          716                                 0
# 477                         1100                                 0
# 478                         1969                                 0
#
#      male_positive_tests_till_date  female_positive_tests_till_date  \
# 0                           179247                           117625
# 1                           182779                           120007
# 2                           186156                           122464
# 3                           193226                           127100
# 4                           196744                           129472
# ..                             ...                              ...
# 474                        1604882                          1144614
# 475                        1605836                          1145254
# 476                        1606848                          1145970
# 477                        1608479                          1147070
# 478                        1611372                          1149039
#
#      transgender_positive_tests_till_date  discharged_today  discharged_total  \
# 0                                      29              6020            238638
# 1                                      29              6037            244675
# 2                                      29              6005            250680
# 3                                      29              5146            261459
# 4                                      29              5556            267015
# ..                                    ...               ...               ...
# 474                                    38               611           2704410
# 475                                    38               624           2705034
# 476                                    38               662           2705696
# 477                                    38               674           2706370
# 478                                    38               688           2707058
#
#      deaths_today  deaths_total  deaths_private_hospitals  \
# 0             119          4927                        34
# 1             114          5041                        34
# 2             118          5159                        47
# 3             119          5397                        38
# 4             117          5514                        34
# ..            ...           ...                       ...
# 474             8         36784                         4
# 475             6         36790                         2
# 476             6         36796                         1
# 477             9         36805                         4
# 478             9         36814                         5
#
#      deaths_government_hopitals
# 0                            85
# 1                            80
# 2                            71
# 3                            81
# 4                            83
# ..                          ...
# 474                           4
# 475                           4
# 476                           5
# 477                           5
# 478                           4
#
# [479 rows x 20 columns]

# %%
TMcaseinfo.drop(columns=["testing_facilities","government_testing_facilities","private_testing_facilities"],inplace=True)

# %%
TMcaseinfo["month"]=TMcaseinfo["date"].copy()
TMcaseinfo["year"]=TMcaseinfo["date"].copy()
TMcaseinfo["month"]=TMcaseinfo["month"].apply(lambda x:get_month(x))
TMcaseinfo["year"]=TMcaseinfo["year"].apply(lambda x:get_year(x))
TMcaseinfo['rise in cases']= ""
TMcaseinfo['rise in cases'] = TMcaseinfo['active_cases_today'].diff()
TMcaseinfo.dropna(subset=['rise in cases'],inplace=True)

# %%
TMcaseinfo
# Out:
#            date  active_cases_yesterday  positive_tested_cases  \
# 1    24-07-2020                   52939                   6785
# 2    25-07-2020                   53132                   6988
# 3    26-07-2020                   52273                   6986
# 4    28-07-2020                   54896                   6972
# 5    29-07-2020                   57073                   6426
# ..          ...                     ...                    ...
# 490  01-01-2022                    7470                   1489
# 491  02-01-2022                    8340                   1594
# 492  03-01-2022                    9304                   1728
# 493  04-01-2022                   10364                   2731
# 494  05-01-2022                   12412                   4862
#
#      discharged_patients  deaths_today  active_cases_today        month year  \
# 1                   6504            88               53132     July2020   24
# 2                   7758            89               52273     July2020   25
# 3                   5471            85               53703     July2020   26
# 4                   4707            88               57073     July2020   28
# 5                   5927            82               57490     July2020   29
# ..                   ...           ...                 ...          ...  ...
# 490                  611             8                8340  January2022   01
# 491                  624             6                9304  January2022   02
# 492                  662             6               10364  January2022   03
# 493                  674             9               12412  January2022   04
# 494                  688             9               16577  January2022   05
#
#      rise in cases
# 1            193.0
# 2           -859.0
# 3           1430.0
# 4           3370.0
# 5            417.0
# ..             ...
# 490          870.0
# 491          964.0
# 492         1060.0
# 493         2048.0
# 494         4165.0
#
# [494 rows x 9 columns]

# %% [markdown]
# # PART1: COVID-WAVES AND ITS POTENTIAL CAUSES:

# %% [markdown]
# ## Graph1
# **The below graph plots no of positives cases, discharged patients, and deaths per day**

# %% [markdown]
# PROPERTIES OF GRAPH1:
# Blue curve:
# 1) If the curve is going up --> means number of cases per day are increasing
# 2) If the curve is going down --> means the number of cases per day are decreasing
# 3) If the curve is flat --> means there is no change in the number cases per day
#
#   Orange curve:
# 1) If the curve is going up --> means number of discharged patients per day is increasing
# 2) If the curve is going down --> means the number of discharged patients per day is decreasing
# 3) If the curve is flat --> means there is no change in the number discharged patients per day

# %%
plt.rcParams['figure.figsize'] = [25,12]
plt.xlabel("date")
plt.plot(TMcaseinfo["date"],TMcaseinfo["positive_tested_cases"], linestyle='-')
plt.plot(TMcaseinfo["date"],TMcaseinfo["discharged_patients"], linestyle='-')
plt.legend(["positive_tested_cases","discharged_patients","deaths_today"])

# %% [markdown]
# ## Graph 2
# **PHASE-1: JULY2020 to DECEMBER2020**

# %% [markdown]
# PROPERTIES OF GRAPH2:
# Blue curve:
# 1) If the curve is going up --> means number of cases per day are increasing
# 2) If the curve is going down --> means the number of cases per day are decreasing
# 3) If the curve is flat --> means there is no change in the number cases per day
#
#   Orange curve:
# 1) If the curve is going up --> means number of discharged patients per day is increasing
# 2) If the curve is going down --> means the number of discharged patients per day is decreasing
# 3) If the curve is flat --> means there is no change in the number discharged patients per day

# %%
plt.rcParams['figure.figsize'] = [30,12]
plt.xlabel("date")
plt.plot(TMcaseinfo["date"][:list(TMcaseinfo["date"]).index("01-01-2021")],TMcaseinfo["positive_tested_cases"][:list(TMcaseinfo["date"]).index("01-01-2021")], linestyle='-')
plt.plot(TMcaseinfo["date"][:list(TMcaseinfo["date"]).index("01-01-2021")],TMcaseinfo["discharged_patients"][:list(TMcaseinfo["date"]).index("01-01-2021")], linestyle='-')
plt.legend(["positive_tested_cases","discharged_patients","deaths_today"])

# %% [markdown]
#  ## Graph3
#  **PHASE2: JANUARY-2021 to SEPTEMBER-2021:**

# %% [markdown]
# PROPERTIES OF GRAPH3:
# Blue curve:
# 1) If the curve is going up --> means number of cases per day are increasing
# 2) If the curve is going down --> means the number of cases per day are decreasing
# 3) If the curve is flat --> means there is no change in the number cases per day
#
#   Orange curve:
# 1) If the curve is going up --> means number of discharged patients per day is increasing
# 2) If the curve is going down --> means the number of discharged patients per day is decreasing
# 3) If the curve is flat --> means there is no change in the number discharged patients per day

# %%
TMcaseinfo
# Out:
#            date  active_cases_yesterday  positive_tested_cases  \
# 1    24-07-2020                   52939                   6785
# 2    25-07-2020                   53132                   6988
# 3    26-07-2020                   52273                   6986
# 4    28-07-2020                   54896                   6972
# 5    29-07-2020                   57073                   6426
# ..          ...                     ...                    ...
# 490  01-01-2022                    7470                   1489
# 491  02-01-2022                    8340                   1594
# 492  03-01-2022                    9304                   1728
# 493  04-01-2022                   10364                   2731
# 494  05-01-2022                   12412                   4862
#
#      discharged_patients  deaths_today  active_cases_today        month year  \
# 1                   6504            88               53132     July2020   24
# 2                   7758            89               52273     July2020   25
# 3                   5471            85               53703     July2020   26
# 4                   4707            88               57073     July2020   28
# 5                   5927            82               57490     July2020   29
# ..                   ...           ...                 ...          ...  ...
# 490                  611             8                8340  January2022   01
# 491                  624             6                9304  January2022   02
# 492                  662             6               10364  January2022   03
# 493                  674             9               12412  January2022   04
# 494                  688             9               16577  January2022   05
#
#      rise in cases
# 1            193.0
# 2           -859.0
# 3           1430.0
# 4           3370.0
# 5            417.0
# ..             ...
# 490          870.0
# 491          964.0
# 492         1060.0
# 493         2048.0
# 494         4165.0
#
# [494 rows x 9 columns]

# %%
plt.rcParams['figure.figsize'] = [15,12]
plt.xlabel("date")
plt.plot(TMcaseinfo["date"][list(TMcaseinfo["date"]).index("01-01-2021"):list(TMcaseinfo["date"]).index("01-07-2021")],TMcaseinfo["positive_tested_cases"][list(TMcaseinfo["date"]).index("01-01-2021"):list(TMcaseinfo["date"]).index("01-07-2021")], linestyle='-')
plt.plot(TMcaseinfo["date"][list(TMcaseinfo["date"]).index("01-01-2021"):list(TMcaseinfo["date"]).index("01-07-2021")],TMcaseinfo["discharged_patients"][list(TMcaseinfo["date"]).index("01-01-2021"):list(TMcaseinfo["date"]).index("01-07-2021")], linestyle='-')
plt.legend(["positive_tested_cases","discharged_patients","deaths_today"])

# %%
TMcaseinfosum=TMcaseinfo.groupby("month").agg("sum").reset_index()
TMcaseinfosum["index"]=TMcaseinfosum["month"].copy()
TMcaseinfosum["index"]=TMcaseinfosum["index"].apply(lambda x: set_index(x))
TMcaseinfosum.sort_values(by="index",inplace=True)
TMcaseinfosum
# Out:
#             month  active_cases_yesterday  positive_tested_cases  \
# 8        July2020                  385765                  45902
# 1      August2020                 1401451                 152517
# 17  September2020                 1154573                 135315
# 15    October2020                 1126874                 118592
# 13   November2020                  435049                  52252
# 3    December2020                  287947                  33527
# 6     January2021                  190682                  19777
# 5    February2021                  119462                  13202
# 11      March2021                  210443                  35131
# 0       April2021                 1789019                 280083
# 12        May2021                 5172933                 775823
# 10       June2021                 4010465                 344645
# 9        July2021                  853948                  75170
# 2      August2021                  616606                  55557
# 18  September2021                  433394                  42333
# 16    October2021                  429622                  36251
# 14   November2021                  288868                  24294
# 4    December2021                  223359                  20449
# 7     January2022                   47890                  12404
#
#     discharged_patients  deaths_today  active_cases_today  rise in cases  \
# 8                 41440           626              389601         5029.0
# 1                154016          2828             1397124        -5390.0
# 17               138515          1737             1149636        -6315.0
# 15               139894          1496             1104076       -24099.0
# 13                61500           557              425244       -11112.0
# 3                 35519           383              285572        -2551.0
# 6                 23326           225              186908        -3947.0
# 5                 13594           140              118930         -532.0
# 11                23051           223              222300        11857.0
# 0                179507          1327             1888268        99249.0
# 12               590652          7971             5350133       190418.0
# 10               588407          7612             3759091      -267355.0
# 9                 90072          1392              837654       -17475.0
# 2                 59131           843              612189        -3866.0
# 18                41484           571              433672          300.0
# 16                41073           506              424294        -5658.0
# 14                27177           365              285620        -3248.0
# 4                 20914           284              222610         -774.0
# 7                  3259            38               56997         9107.0
#
#     index
# 8      -1
# 1       0
# 17      1
# 15      2
# 13      3
# 3       4
# 6       5
# 5       6
# 11      7
# 0       8
# 12      9
# 10     10
# 9      11
# 2      12
# 18     13
# 16     14
# 14     15
# 4      16
# 7      17

# %% [markdown]
# ## Graph4
# **DESCRRIPTION:  The below graph plots total no of positives cases per every month from July 2020 to January 2022**

# %%
plt.rcParams['figure.figsize'] = [30,12]
bar_graph(TMcaseinfosum["month"],TMcaseinfosum["positive_tested_cases"],"Month","Total no of cases","Total no cases in each month")

# %% [markdown]
# **Conclusions** from The above graph:
# As we can see the highest total no of cases in a month can be seen in april2021, May2021, June2021

# %% [markdown]
# ## Graph5
# **The below graph plots total no of deaths per every month from July 2020 to January 2022**

# %%
plt.rcParams['figure.figsize'] = [30,12]
bar_graph(TMcaseinfosum["month"],TMcaseinfosum["deaths_today"],"Month","Total no of ceased","Total no deaths in each month")

# %% [markdown]
# **DESCRRIPTION: Conclusions from The above graph:
# As we can see the highest no of deaths in a month can be seen in  May2021, June2021**

# %%
Totalcases=TMcaseinfo["positive_tested_cases"].agg("sum")
TMdistrictsum=TMdistrict.groupby("district").sum().reset_index()
dis=[]
sumdis=[]
for i in range(len(TMdistrictsum["district"])):
    if ((TMdistrictsum["new_cases_today"][i]/Totalcases)*100)>5:
        dis.append(TMdistrictsum["district"][i])
        sumdis.append(TMdistrictsum["new_cases_today"][i])

# %% [markdown]
# ## Graph6
# **The below piechart plots the states that contributed more than 3% to the total no. covid cases of the state**

# %%
piechart(dis,sumdis,"")

# %% [markdown]
# # Pre-requisites:
# 1. The data on which analysis was done starts from July 2020 uptill January 2022 in most cases.
#
# # Summary of Part-1 Analysis:
# ## PHASE-1: JULY2020 to DECEMBER2020:
# *1)* From Graph1 and Graph2 we can observe that the no of covid cases are decreasing from **July2020** to **December2020**. One primary reason the govrnement could acheive that because the lockdown was implemented strictly till **December2020**
# source: https://www.thehindubusinessline.com/news/tn-government-extends-covid-19-lockdown-till-january-31/article33465521.ece
# ## PHASE2: JANUARY-2021 to SEPTEMBER-2021:
# *1)* From graph1 ,graph3 and graph4 we can see that the no of cases were less but we can observe that no. of cases started increasingly drastically from **april2021** till **july2021**. There can be many factors to it but few main reasons can be the Tamil Nadu Legislative Assembly election, 2021 conducted between **6-April-2021** to **2-May-2021**
# source: https://en.wikipedia.org/wiki/2021_Tamil_Nadu_Legislative_Assembly_election.
#
# We can see in graph5 that the no of deaths are very high in **May2021** and **June2021**, We can say that this can be an affect of the huge no of covid cases during the period of **April2021** and **May2021**, shortage of beds, Both private and govt. hospitals are full of patients.
#
#  Graph6 depicts the states that recorded more than 5% of cases to the total no. of cases of the state. As we can see, Chennai accounts 37.68% of total cases of the state. Then follows Coimbatore with 18.55%, Chengalpattu with 12.31%, Thiruvallur with 8.62% etc. We can observe that all these disrticts are mostly urban areas.

# %% [markdown]
# # PART2 Analysis

# %%
TMpositive["day"]=TMpositive.date.copy()
TMpositive["day"]=TMpositive["day"].apply(lambda x: get_day(x))

# %%
TMpositive
# Out:
#            date  active_cases  tested_positive_today  \
# 0    09-08-2020         53336                   5974
# 1    10-08-2020         53099                   5879
# 2    11-08-2020         52810                   5814
# 3    13-08-2020         53499                   5810
# 4    14-08-2020         53716                   5862
# ..          ...           ...                    ...
# 474  01-01-2022          8340                   1470
# 475  02-01-2022          9304                   1575
# 476  03-01-2022         10364                   1727
# 477  04-01-2022         12412                   2683
# 478  05-01-2022         16577                   4824
#
#      tested_positive_till_date  rtpcr_samples_tested_today  \
# 0                       296901                       70186
# 1                       302815                       67153
# 2                       308649                       67492
# 3                       320355                       67275
# 4                       326245                       70153
# ..                         ...                         ...
# 474                    2749534                      103607
# 475                    2751128                      102237
# 476                    2752856                      103119
# 477                    2755587                      103798
# 478                    2760449                      117611
#
#      rtpcr_samples_tested_till_date  persons_tested_rt_pcr_today  \
# 0                           3225805                        68179
# 1                           3292958                        65141
# 2                           3360450                        65490
# 3                           3499300                        65560
# 4                           3569453                        68301
# ..                              ...                          ...
# 474                        57547850                       103403
# 475                        57650087                       102029
# 476                        57753206                       102898
# 477                        57857004                       103573
# 478                        57974615                       117382
#
#      persons_tested_rt_pcr_till_date  male_positive_tests_today  \
# 0                            3109708                       3503
# 1                            3174849                       3532
# 2                            3240339                       3377
# 3                            3375596                       3549
# 4                            3443897                       3518
# ..                               ...                        ...
# 474                         56608042                        895
# 475                         56710071                        954
# 476                         56812969                       1012
# 477                         56916542                       1631
# 478                         57033924                       2893
#
#      female_positive_tests_today  ...  male_positive_tests_till_date  \
# 0                           2489  ...                         179247
# 1                           2382  ...                         182779
# 2                           2457  ...                         186156
# 3                           2286  ...                         193226
# 4                           2372  ...                         196744
# ..                           ...  ...                            ...
# 474                          594  ...                        1604882
# 475                          640  ...                        1605836
# 476                          716  ...                        1606848
# 477                         1100  ...                        1608479
# 478                         1969  ...                        1611372
#
#      female_positive_tests_till_date  transgender_positive_tests_till_date  \
# 0                             117625                                    29
# 1                             120007                                    29
# 2                             122464                                    29
# 3                             127100                                    29
# 4                             129472                                    29
# ..                               ...                                   ...
# 474                          1144614                                    38
# 475                          1145254                                    38
# 476                          1145970                                    38
# 477                          1147070                                    38
# 478                          1149039                                    38
#
#      discharged_today  discharged_total  deaths_today  deaths_total  \
# 0                6020            238638           119          4927
# 1                6037            244675           114          5041
# 2                6005            250680           118          5159
# 3                5146            261459           119          5397
# 4                5556            267015           117          5514
# ..                ...               ...           ...           ...
# 474               611           2704410             8         36784
# 475               624           2705034             6         36790
# 476               662           2705696             6         36796
# 477               674           2706370             9         36805
# 478               688           2707058             9         36814
#
#      deaths_private_hospitals  deaths_government_hopitals        day
# 0                          34                          85     Sunday
# 1                          34                          80     Monday
# 2                          47                          71    Tuesday
# 3                          38                          81   Thursday
# 4                          34                          83     Friday
# ..                        ...                         ...        ...
# 474                         4                           4   Saturday
# 475                         2                           4     Sunday
# 476                         1                           5     Monday
# 477                         4                           5    Tuesday
# 478                         5                           4  Wednesday
#
# [479 rows x 21 columns]

# %%
TMpositiveday=TMpositive.groupby("day")
TMpositiveday.first()
# Out:
#                  date  active_cases  tested_positive_today  \
# day
# Friday     14-08-2020         53716                   5862
# Monday     10-08-2020         53099                   5879
# Saturday   15-08-2020         54213                   5830
# Sunday     09-08-2020         53336                   5974
# Thursday   13-08-2020         53499                   5810
# Tuesday    11-08-2020         52810                   5814
# Wednesday  19-08-2020         53155                   5785
#
#            tested_positive_till_date  rtpcr_samples_tested_today  \
# day
# Friday                        326245                       70153
# Monday                        302815                       67153
# Saturday                      332105                       71343
# Sunday                        296901                       70186
# Thursday                      320355                       67275
# Tuesday                       308649                       67492
# Wednesday                     355449                       67720
#
#            rtpcr_samples_tested_till_date  persons_tested_rt_pcr_today  \
# day
# Friday                            3569453                        68301
# Monday                            3292958                        65141
# Saturday                          3640796                        69598
# Sunday                            3225805                        68179
# Thursday                          3499300                        65560
# Tuesday                           3360450                        65490
# Wednesday                         3913523                        65592
#
#            persons_tested_rt_pcr_till_date  male_positive_tests_today  \
# day
# Friday                             3443897                       3518
# Monday                             3174849                       3532
# Saturday                           3513495                       3509
# Sunday                             3109708                       3503
# Thursday                           3375596                       3549
# Tuesday                            3240339                       3377
# Wednesday                          3778249                       3541
#
#            female_positive_tests_today  transgender_positive_tests_today  \
# day
# Friday                            2372                                 0
# Monday                            2382                                 0
# Saturday                          2351                                 0
# Sunday                            2489                                 2
# Thursday                          2286                                 0
# Tuesday                           2457                                 0
# Wednesday                         2254                                 0
#
#            male_positive_tests_till_date  female_positive_tests_till_date  \
# day
# Friday                            196744                           129472
# Monday                            182779                           120007
# Saturday                          200253                           131823
# Sunday                            179247                           117625
# Thursday                          193226                           127100
# Tuesday                           186156                           122464
# Wednesday                         214494                           140926
#
#            transgender_positive_tests_till_date  discharged_today  \
# day
# Friday                                       29              5556
# Monday                                       29              6037
# Saturday                                     29              5236
# Sunday                                       29              6020
# Thursday                                     29              5146
# Tuesday                                      29              6005
# Wednesday                                    29              6384
#
#            discharged_total  deaths_today  deaths_total  \
# day
# Friday               267015           117          5514
# Monday               244675           114          5041
# Saturday             272251           127          5641
# Sunday               238638           119          4927
# Thursday             261459           119          5397
# Tuesday              250680           118          5159
# Wednesday            296171           116          6123
#
#            deaths_private_hospitals  deaths_government_hopitals
# day
# Friday                           34                          83
# Monday                           34                          80
# Saturday                         44                          83
# Sunday                           34                          85
# Thursday                         38                          81
# Tuesday                          47                          71
# Wednesday                        32                          84

# %% [markdown]
# ##  Graph7
# **The graph below depicts no. of tests conducted per day**

# %%
plt.rcParams['figure.figsize'] = [25,12]
plt.plot(TMpositive["date"],TMpositive["rtpcr_samples_tested_today"])

# %% [markdown]
# **Description: We can observe that the no. of cases increased drastically during second-wave. One major reason can be that govt. decided to test even symptomatic as well as asymptomatic, primary contacts, secondary contacts.**

# %%
TMpositive["TPR"]=TMpositive.apply(lambda x: TPR(x["rtpcr_samples_tested_today"],x["tested_positive_today"]),axis=1)
TMpositive
# Out:
#            date  active_cases  tested_positive_today  \
# 0    09-08-2020         53336                   5974
# 1    10-08-2020         53099                   5879
# 2    11-08-2020         52810                   5814
# 3    13-08-2020         53499                   5810
# 4    14-08-2020         53716                   5862
# ..          ...           ...                    ...
# 474  01-01-2022          8340                   1470
# 475  02-01-2022          9304                   1575
# 476  03-01-2022         10364                   1727
# 477  04-01-2022         12412                   2683
# 478  05-01-2022         16577                   4824
#
#      tested_positive_till_date  rtpcr_samples_tested_today  \
# 0                       296901                       70186
# 1                       302815                       67153
# 2                       308649                       67492
# 3                       320355                       67275
# 4                       326245                       70153
# ..                         ...                         ...
# 474                    2749534                      103607
# 475                    2751128                      102237
# 476                    2752856                      103119
# 477                    2755587                      103798
# 478                    2760449                      117611
#
#      rtpcr_samples_tested_till_date  persons_tested_rt_pcr_today  \
# 0                           3225805                        68179
# 1                           3292958                        65141
# 2                           3360450                        65490
# 3                           3499300                        65560
# 4                           3569453                        68301
# ..                              ...                          ...
# 474                        57547850                       103403
# 475                        57650087                       102029
# 476                        57753206                       102898
# 477                        57857004                       103573
# 478                        57974615                       117382
#
#      persons_tested_rt_pcr_till_date  male_positive_tests_today  \
# 0                            3109708                       3503
# 1                            3174849                       3532
# 2                            3240339                       3377
# 3                            3375596                       3549
# 4                            3443897                       3518
# ..                               ...                        ...
# 474                         56608042                        895
# 475                         56710071                        954
# 476                         56812969                       1012
# 477                         56916542                       1631
# 478                         57033924                       2893
#
#      female_positive_tests_today  ...  female_positive_tests_till_date  \
# 0                           2489  ...                           117625
# 1                           2382  ...                           120007
# 2                           2457  ...                           122464
# 3                           2286  ...                           127100
# 4                           2372  ...                           129472
# ..                           ...  ...                              ...
# 474                          594  ...                          1144614
# 475                          640  ...                          1145254
# 476                          716  ...                          1145970
# 477                         1100  ...                          1147070
# 478                         1969  ...                          1149039
#
#      transgender_positive_tests_till_date  discharged_today  discharged_total  \
# 0                                      29              6020            238638
# 1                                      29              6037            244675
# 2                                      29              6005            250680
# 3                                      29              5146            261459
# 4                                      29              5556            267015
# ..                                    ...               ...               ...
# 474                                    38               611           2704410
# 475                                    38               624           2705034
# 476                                    38               662           2705696
# 477                                    38               674           2706370
# 478                                    38               688           2707058
#
#      deaths_today  deaths_total  deaths_private_hospitals  \
# 0             119          4927                        34
# 1             114          5041                        34
# 2             118          5159                        47
# 3             119          5397                        38
# 4             117          5514                        34
# ..            ...           ...                       ...
# 474             8         36784                         4
# 475             6         36790                         2
# 476             6         36796                         1
# 477             9         36805                         4
# 478             9         36814                         5
#
#      deaths_government_hopitals        day       TPR
# 0                            85     Sunday  8.511669
# 1                            80     Monday  8.754635
# 2                            71    Tuesday  8.614354
# 3                            81   Thursday  8.636195
# 4                            83     Friday  8.356022
# ..                          ...        ...       ...
# 474                           4   Saturday  1.418823
# 475                           4     Sunday  1.540538
# 476                           5     Monday  1.674764
# 477                           5    Tuesday  2.584828
# 478                           4  Wednesday  4.101657
#
# [479 rows x 22 columns]

# %% [markdown]
# ##  Graph8
# **The graph below plots the TPR(Test positivity Rate)**

# %%
plt.rcParams['figure.figsize'] = [25,12]
plt.xlabel("date")
plt.ylabel("TPR in %")
plt.plot(TMpositive["date"][list(TMpositive["date"]).index("01-01-2021"):list(TMpositive["date"]).index("01-07-2021")],TMpositive["TPR"][list(TMpositive["date"]).index("01-01-2021"):list(TMpositive["date"]).index("01-07-2021")])

# %% [markdown]
# **Description: From the above graph, we can infer that the TPR(Test Positivity Rate) drastically increased  during second-wave. The highest TPR recorded in the state was 21.16%.**

# %% [markdown]
#  # PART3: AFFECT OF COMORBIDITY ON COVID PATIENT

# %%
TNindividual
# Out:
#              date  case_id                                           category  \
# 0      27-05-2021    22007  Government Health Facilities (DME) Due To Como...
# 1      26-05-2021    21752     Private health facilities due to comorbidities
# 2      26-05-2021    21572  Government health facilities (DMS) without com...
# 3      27-05-2021    22225     Private Health Facilities Due To Comorbidities
# 4      08-05-2021    15289    Private health facilities without comorbidities
# ...           ...      ...                                                ...
# 28956  07-10-2021    35733  Other facilities (Other Institutions like Rail...
# 28957  07-10-2021    35734  Other facilities (Other Institutions like Rail...
# 28958  03-11-2021   360176  Other facilities (Other Institutions like Rail...
# 28959  08-11-2021    36201  Government health facilities (DME) due to como...
# 28960  05-01-2022    36812  Government health facilities (DME) due to como...
#
#        age  gender                                           location  \
# 0       65  Female                                            Vellore
# 1       59  Female                                            Madurai
# 2       62    Male                                       Virudhunagar
# 3       37  Female                                            Vellore
# 4       64  Famale                                        Tirunelveli
# ...    ...     ...                                                ...
# 28956   80  female                                            Chennai
# 28957   80    male                                            Chennai
# 28958   86  female                                            Chennai
# 28959   58    male  Coimbatore died on 04.11.2021 at 08.00 AM due ...
# 28960   77  Female                                        Krishnagiri
#
#                                              comorbidity   test_date  \
# 0                                                    NaN  23-05-2021
# 1                                                with DM  21-04-2021
# 2                                                    NaN  15-05-2021
# 3                                              with SHTN  11-05-2021
# 4                                                    NaN  02-05-2021
# ...                                                  ...         ...
# 28956                                                NaN  06-09-2021
# 28957                                                NaN  19-10-2020
# 28958                                                NaN  23-10-2021
# 28959                                                NaN         NaN
# 28960  with Systemic Hypertension brought dead on 01....         NaN
#
#                                  test_details  \
# 0                  COVID test positive result
# 1                   COVID-19 RTPCR Positivity
# 2                   COVID-19 RTPCR Positivity
# 3                   COVID-19 RTPCR Positivity
# 4                   COVID-19 RTPCR Positivity
# ...                                       ...
# 28956                       symptoms of fever
# 28957  symptoms of fever, cough and body pain
# 28958    symptoms of fever and breathlessness
# 28959                                     NaN
# 28960                                     NaN
#
#                                admission_location admission_date  \
# 0                         Vellore Medical College     22.0502021
# 1                       private hospital, Madurai      30.042021
# 2       Government Hospital, Sattur, Virudhunagar      1705.2021
# 3                        private hospital,Vellore     10-05-2001
# 4      private hospital, Tirunelveli, Tirunelveli     03-05-2011
# ...                                           ...            ...
# 28956                                         NaN            NaN
# 28957                                         NaN            NaN
# 28958                                         NaN            NaN
# 28959                                         NaN            NaN
# 28960                                         NaN            NaN
#
#       admission_time  admission_symptoms_days  \
# 0            09.20PM                      NaN
# 1           12:00 AM                      NaN
# 2           05.00 PM                      NaN
# 3           10.00 AM                      2.0
# 4            5.21.PM                      3.0
# ...              ...                      ...
# 28956            NaN                      NaN
# 28957            NaN                      NaN
# 28958            NaN                      NaN
# 28959            NaN                      NaN
# 28960            NaN                      NaN
#
#                               admission_symptoms_details         death_cause  \
# 0                                                    NaN  COVID-19 Pneumonia
# 1                      Cough and Difficulty in Breathing  COVID-19 Pneumonia
# 2                                                  Cough  COVID-19 Pneumonia
# 3      Fever and Cough in 3 days, Difficulty in Breat...  COVID 19 Pneumonia
# 4                                           Fever, Cough  COVID-19 Pneumonia
# ...                                                  ...                 ...
# 28956                                                NaN                 NaN
# 28957                                                NaN                 NaN
# 28958                                                NaN                 NaN
# 28959                                                NaN                 NaN
# 28960                                                NaN                 NaN
#
#        death_date death_time  \
# 0      26-05-2021    03.20AM
# 1      07-05-2021    8.55 PM
# 2      24-05-2021   06.45 AM
# 3      25-05-2021    7.04 PM
# 4      06-05-2021   07.20.AM
# ...           ...        ...
# 28956         NaN        NaN
# 28957         NaN        NaN
# 28958         NaN        NaN
# 28959         NaN        NaN
# 28960         NaN        NaN
#
#                                                 raw_data
# 0      A 65 years old Female from Vellore admitted on...
# 1      A 59 Years old Female from Madurai having COVI...
# 2      A 62 Years old Male from Virudhunagar having C...
# 3      A 37 Years old Female from Vellore having COVI...
# 4      A 64 Years old Famale from Tirunelveli having ...
# ...                                                  ...
# 28956  A 80 Years old female from Chennai having symp...
# 28957  A 80 Years old male from Chennai having sympto...
# 28958  A 86 Years old female from Chennai having symp...
# 28959  A 58 years old male from Coimbatore died on 04...
# 28960  A 77 years old Female from Krishnagiri with Sy...
#
# [28961 rows x 18 columns]

# %%
TNindividual["comorbidity"]=TNindividual["comorbidity"].fillna("no comorbidity")
TNindividual["comorb"]=TNindividual.comorbidity.copy()
TNindividual["comorb"]=TNindividual["comorb"].apply(lambda x: comorb(x))
TNindividual["comorb"]
# Out:
# 0        no comorbidity
# 1           comorbidity
# 2        no comorbidity
# 3           comorbidity
# 4        no comorbidity
#               ...
# 28956    no comorbidity
# 28957    no comorbidity
# 28958    no comorbidity
# 28959    no comorbidity
# 28960       comorbidity
# Name: comorb, Length: 28961, dtype: object

# %% [markdown]
# ## Graph9
# **The below piechart depicts the no. of deaths with/without comorbidity**

# %%
TNindividualgrp=list(TNindividual.groupby("comorb").size())
piechart(["people with comorbidity","people without comorbidity"],TNindividualgrp,"Deaths with/without comorbidity")

# %% [markdown]
# **DESCRRIPTION: From Graph9 we can observe that the no of deaths in people with comobidities is higher than people without comorbidities**

# %%
TNindividual["category"]=TNindividual["category"].apply(lambda x: cato(x))
TNindividualsi=(TNindividual.groupby("category").size())

# %%
TNindividualsi
# Out:
# category
# Government facility    17435
# Medical college            3
# Others                   547
# Private facility       10976
# dtype: int64

# %% [markdown]
# ## Graph10
# **The below piechart depicts the no. of deaths in govt. vs private hospitals**

# %%
TNindividualsi=list(TNindividual.groupby("category").size())
piechart(["Government facility","Private facility"],TNindividualsi)

# %% [markdown]
# **DESCRRIPTION: From Graph 10 we can say that deaths in govt. are more compared to deaths in private hospitals**

# %% [markdown]
# ## Graph11
# **The below piechart depicts the no. of deaths in above 40 age group vs 40 group comorbidity**

# %%
TNindividual.sort_values("age",inplace=True)
age40mins=TNindividual.query("age<40")
age40plus=TNindividual.query("age>40")
age40pluscount=age40plus["age"].count()
age40minuscount=age40mins["age"].count()
piechart(["age40pluscount","age40minuscount"],[age40pluscount,age40minuscount],"deaths in above 40 vs below 40")

# %% [markdown]
# **DESCRRIPTION: From Graph11 we can infer that the no. deaths in above 40 age group is very high compared to below 40 age group**

# %% [markdown]
# ## Graph12
# **The below bargraph depicts the no. of deaths in 40+ age group with vs without comorbodities**

# %%
plt.rcParams['figure.figsize'] = [5,12]
age40nocomorbidity=TNindividual.query("age>40 and comorb=='no comorbidity'")
age40comorbidity=TNindividual.query("age>40 and comorb=='comorbidity'")
age40nocomorbiditycount=age40nocomorbidity["age"].count()
age40comorbiditycount=age40comorbidity["age"].count()
bar_graph(["age40nocomorbidity","age40comorbidity"],[age40nocomorbiditycount,age40comorbiditycount]," ","","")

# %% [markdown]
# **Description: From Graph12 we can observe that the deaths in age above 40 were very high in cases with  comorbidities compared to cases with no comorbodities. Almost 65% more than deaths of people with no comorbidities.**
